# %% [markdown]
# # FluoroFate
#
# Napari-based GUI for fluorescence cell-death / cell-fate analysis.
# See [FluoroFate_README.md](FluoroFate_README.md) for full documentation.
#
# ## Pipeline
# 1. **Cellpose** segments brightfield frames into cell masks
# 2. **TrackMate** links cell identities across frames (headless via PyImageJ)
# 3. **Fluorescence thresholding** identifies positive regions per fluorophore (up to 3)
# 4. **Fate assignment** classifies cells in one of two modes:
#    - **Persistent** — first fluorophore to appear determines permanent fate (e.g. Annexin V / PI)
#    - **Snapshot** — per-frame classification by current active fluorophores (e.g. FUCCI)
# 5. **Outputs** — percentage trajectory plots, spatial trajectory plots, and cell-level CSVs (with positive area per fluorophore) at multiple frame-presence cutoffs
#
# ## Staged Workflow
# | Button | Description |
# |---|---|
# | **1) Run Segmentation** | Cellpose only → saves `masks_stack.tiff` |
# | **2) Run Tracking** | TrackMate only → saves linked labels + tracks CSV |

# %%
from fluorofate import launch

app = launch()
# Out:
# model_type argument is not used in v4.0.1+. Ignoring this argument...
# [Cellpose] Loading model: cpsam
# [Cellpose] Estimated diameter: 61.4 px
# [Cellpose] Segmenting 7 frame(s) (diameter=61.4, flow_thresh=0.4, cellprob_thresh=0.0, min_size=15)...
# [Cellpose] Frame 1/7 — 1144 cell(s) detected
# [Cellpose] Frame 2/7 — 1158 cell(s) detected
# [Cellpose] Frame 3/7 — 1192 cell(s) detected
# [Cellpose] Frame 4/7 — 1147 cell(s) detected
# [Cellpose] Frame 5/7 — 1156 cell(s) detected
# [Cellpose] Frame 6/7 — 1185 cell(s) detected
# [Cellpose] Frame 7/7 — 1198 cell(s) detected
# [Cellpose] Segmentation complete. Processed 7 frame(s).
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 2560x1839+0+29 (frame: 2578x1886-9-9) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1409". Resulting geometry: 2560x1351+0+29 (frame: 2578x1398-9-9) margins: 9, 38, 9, 9 minimum size: 668x1471 MINMAXINFO(maxSize=POINT(x=0, y=0), maxpos=POINT(x=0, y=0), maxtrack=POINT(x=0, y=0), mintrack=POINT(x=853, y=1886)))
